# %% [markdown]
# APRIORI ALGORITHM - ASSOCIATION

# %%
#Import Libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

# %%
#Read the data set
store_data = pd.read_csv("Market_Busket.csv")

# %%
store_data.head(3)
# Out:
#               Item 1         Item 2     Item 3         Item 4   Item 5 Item 6  \
# 0            burgers        cookies  spaghetti           eggs      NaN    NaN
# 1               eggs  mineral water  spaghetti      chocolate  cookies    NaN
# 2  frozen vegetables      chocolate    cookies  mineral water      NaN    NaN
#
#   Item 7  Item 8  Item 9  Item 10
# 0    NaN     NaN     NaN      NaN
# 1    NaN     NaN     NaN      NaN
# 2    NaN     NaN     NaN      NaN

# %%
#prepare lists for trasactions
records = []
for i in range(0, 7499):
    records.append([str(store_data.values[i,j]) for j in range(0, 10) if pd.notnull(store_data.values[i,j])])

# %%
#Pre processing the data(using translation encoder)
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)

# %%
df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#       burgers  chocolate  cookies   eggs  frozen vegetables  grated cheese  \
# 0        True      False     True   True              False          False
# 1       False       True     True   True              False          False
# 2       False       True     True  False               True          False
# 3        True      False    False   True              False          False
# 4       False       True    False   True              False          False
# ...       ...        ...      ...    ...                ...            ...
# 7494     True       True    False   True               True          False
# 7495    False      False    False   True              False          False
# 7496    False       True    False   True               True          False
# 7497    False      False     True   True              False          False
# 7498    False       True    False   True              False          False
#
#          in  mineral water  shrimp  spaghetti  turkey
# ...

# %%
#remove unnessasary column which is generated by TransactionEncoder
df = df.drop(columns = 'in')

# %%
df
# Out:
#       burgers  chocolate  cookies   eggs  frozen vegetables  grated cheese  \
# 0        True      False     True   True              False          False
# 1       False       True     True   True              False          False
# 2       False       True     True  False               True          False
# 3        True      False    False   True              False          False
# 4       False       True    False   True              False          False
# ...       ...        ...      ...    ...                ...            ...
# 7494     True       True    False   True               True          False
# 7495    False      False    False   True              False          False
# 7496    False       True    False   True               True          False
# 7497    False      False     True   True              False          False
# 7498    False       True    False   True              False          False
#
#       mineral water  shrimp  spaghetti  turkey
# ...

# %%
#Apriori Algorithm 
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.25)
# Out:
#      support   itemsets
# 0   0.667022        (1)
# 1   0.371783        (2)
# 2   0.787838        (3)
# 3   0.664355        (6)
# 4   0.547140        (8)
# 5   0.496866     (1, 3)
# 6   0.421390     (1, 6)
# 7   0.340312     (8, 1)
# 8   0.271236     (2, 3)
# 9   0.503534     (3, 6)
# 10  0.413789     (8, 3)
# 11  0.337378     (8, 6)
# 12  0.297240  (1, 3, 6)

# %%
apriori(df, min_support=0.25, use_colnames=True)
# Out:
#      support                          itemsets
# 0   0.667022                       (chocolate)
# 1   0.371783                         (cookies)
# 2   0.787838                            (eggs)
# 3   0.664355                   (mineral water)
# 4   0.547140                       (spaghetti)
# 5   0.496866                 (eggs, chocolate)
# 6   0.421390        (mineral water, chocolate)
# 7   0.340312            (chocolate, spaghetti)
# 8   0.271236                   (cookies, eggs)
# 9   0.503534             (mineral water, eggs)
# 10  0.413789                 (eggs, spaghetti)
# 11  0.337378        (mineral water, spaghetti)
# 12  0.297240  (mineral water, eggs, chocolate)

# %%
#find frequent item sets
frequent_itemsets = apriori(df, min_support=0.25, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets
# Out:
#      support                          itemsets  length
# 0   0.667022                       (chocolate)       1
# 1   0.371783                         (cookies)       1
# 2   0.787838                            (eggs)       1
# 3   0.664355                   (mineral water)       1
# 4   0.547140                       (spaghetti)       1
# 5   0.496866                 (eggs, chocolate)       2
# 6   0.421390        (mineral water, chocolate)       2
# 7   0.340312            (chocolate, spaghetti)       2
# 8   0.271236                   (cookies, eggs)       2
# 9   0.503534             (mineral water, eggs)       2
# 10  0.413789                 (eggs, spaghetti)       2
# 11  0.337378        (mineral water, spaghetti)       2
# 12  0.297240  (mineral water, eggs, chocolate)       3
